# %% [markdown]
# ## Numeric
# - Integer
# - Float
# - Complex
# ## Text
# - String
#
# ## Sequence
# - List
# - Tuple
# - Range(start, stop, step)
#
# ## Mapping Type
# - Dictionary
#
# ## Set Data Type
# ## Boolean
# ## None

# %%
a = 4
b = 6
print(a,b)
# Out:
# 4 6

# %%
x = int(input("Enter your age: "))
print("Your age is", x)
print(f"Your are {x} years old")
# Out:
# Your age is 32
# Your are 32 years old

# %%
# Compute age from year of birth
# Store your name, age and location as dictionary
# Create a to-do list using Python lists
# Create list of odd numbers from 100 to 1 using range
# print the second item from your to-do list
# print the second last item from your to-do list
# print the number of characters in your name
# Write code to do basic arithmetic(+-*/) on two numbers accepted from user
# Print age and year of birth accepting user input and print formatting
# Write code to print a greeting message 5 times
# Write code to print (True/False) a given string is palindrome
# Write code to print a digit in words (e.g. 3 --> Three)
# Write code to print a 4-digit otp in words (e.g. 2136 --> Two One Three Six)
# Write code to print a 4-digit word in digits (e.g. Two One Three Six -->2136)

# %%
digits = ["Zero", "One", "Two", "Three", "Four",\
    "Five", "Six", "Seven", "Eight", "Nine"]
otp = input("Enter otp : ")
a,b,c,d = int(otp[0]), int(otp[1]), int(otp[2]), int(otp[3])
print(digits[a], digits[b], digits[c], digits[d])
# Out:
# Two Four Three Nine
